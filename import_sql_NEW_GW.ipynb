# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from sqlalchemy import create_engine
from config import postgresPass as pw

# %%
protocol = 'postgresql'
username = 'postgres'
password = pw
host = 'localhost'
port = 5432
database_name = 'bike_shop'
engine = create_engine(f'{protocol}://{username}:{password}@{host}:{port}/{database_name}')
   
connection = engine.connect()

# %%
categories = pd.read_sql('select * from categories', connection)

# %%
categories.head()
# Out:
#    ProductSubcategoryKey  SubcategoryName  ProductCategoryKey CategoryName
# 0                      1   Mountain Bikes                   1        Bikes
# 1                      2       Road Bikes                   1        Bikes
# 2                      3    Touring Bikes                   1        Bikes
# 3                      4       Handlebars                   2   Components
# 4                      5  Bottom Brackets                   2   Components

# %%
products = pd.read_sql('select * from products', connection)

# %%
products.head()
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         530                     37    TT-T092        Touring Tire Tube
# 1         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 2         215                     31    HL-U509  Sport-100 Helmet, Black
# 3         218                     23  SO-B909-M   Mountain Bike Socks, M
# 4         219                     23  SO-B909-L   Mountain Bike Socks, L
#
#              ModelName                                 ProductDescription  \
# 0    Touring Tire Tube                              General purpose tube.
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2            Sport-100  Universal fit, well-vented, lightweight , snap...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4  Mountain Bike Socks  Combination of natural and synthetic fibers st...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# ...

# %%
territories = pd.read_sql('select * from territories', connection)

# %%
territories.head()
# Out:
#    SalesTerritoryKey     Region        Country      Continent
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America

# %%
returns = pd.read_sql('select * from returns', connection)

# %%
returns.head()
# Out:
#    ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0  2015-01-18             9         312               1
# 1  2015-01-18            10         310               1
# 2  2015-01-21             8         346               1
# 3  2015-01-22             4         311               1
# 4  2015-02-02             6         312               1

# %%
calendar = pd.read_sql('select * from calendar', connection)

# %%
calendar.head()
# Out:
#          Date
# 0  2015-01-01
# 1  2015-01-02
# 2  2015-01-03
# 3  2015-01-04
# 4  2015-01-05

# %%
customers = pd.read_sql('select * from customers', connection)

# %%
customers.head()
# Out:
#    CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG  1966-04-08             M      M
# 1        11001    MR.     EUGENE    HUANG  1965-05-14             S      M
# 2        11002    MR.      RUBEN   TORRES  1965-08-12             M      M
# 3        11003    MS.    CHRISTY      ZHU  1968-02-15             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON  1968-08-08             S      F
#
#                      EmailAddress  AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com         90000              2      Bachelors
# 1    eugene10@adventure-works.com         60000              3      Bachelors
# 2     ruben35@adventure-works.com         60000              3      Bachelors
# 3   christy12@adventure-works.com         70000              0      Bachelors
# 4  elizabeth5@adventure-works.com         80000              5      Bachelors
#
#      Occupation HomeOwner
# ...

# %%
combined_product_sales = pd.read_sql('select * from combined_product_sales', connection)

# %%
combined_product_sales.head()
# Out:
#    ProductSubcategoryKey SubcategoryName  ProductCategoryKey CategoryName  \
# 0                      2      Road Bikes                   1        Bikes
# 1                      2      Road Bikes                   1        Bikes
# 2                      1  Mountain Bikes                   1        Bikes
# 3                      2      Road Bikes                   1        Bikes
# 4                      2      Road Bikes                   1        Bikes
#
#    ProductKey  ProductSKU             ProductName     ModelName  \
# 0         332  BK-R50B-58      Road-650 Black, 58      Road-650
# 1         312  BK-R93R-48        Road-150 Red, 48      Road-150
# 2         350  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3         338  BK-R50B-44      Road-650 Black, 44      Road-650
# 4         312  BK-R93R-48        Road-150 Red, 48      Road-150
#
#                                   ProductDescription ProductColor  ...  \
# ...

# %%
print(combined_product_sales.columns)
# Out:
# Index(['ProductSubcategoryKey', 'SubcategoryName', 'ProductCategoryKey',
#        'CategoryName', 'ProductKey', 'ProductSKU', 'ProductName', 'ModelName',
#        'ProductDescription', 'ProductColor', 'ProductSize', 'ProductStyle',
#        'ProductCost', 'ProductPrice', 'SalesTerritoryKey', 'Region', 'Country',
#        'Continent', 'OrderDate', 'StockDate', 'OrderNumber', 'CustomerKey',
#        'OrderLineItem', 'OrderQuantity'],
#       dtype='object')

# %%
combined_product_sales.describe()
# Out:
#        ProductSubcategoryKey  ProductCategoryKey    ProductKey   ProductCost  \
# count           56046.000000        56046.000000  56046.000000  56046.000000
# mean               23.412982            3.102576    438.962103    255.801877
# std                13.493235            1.258273    118.612352    496.230445
# min                 1.000000            1.000000    214.000000      1.000000
# 25%                19.000000            3.000000    360.000000      3.000000
# 50%                28.000000            4.000000    479.000000     11.000000
# 75%                37.000000            4.000000    529.000000     59.000000
# max                37.000000            4.000000    606.000000   2171.000000
#
#        ProductPrice  SalesTerritoryKey   CustomerKey  OrderLineItem  \
# count  56046.000000       56046.000000  56046.000000   56046.000000
# mean     438.977465           6.254666  18843.645559       1.903151
# std      838.590106           2.958005   5412.449843       1.021006
# ...
