# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from sqlalchemy import create_engine
from config import postgresPass as pw

# %%
protocol = 'postgresql'
username = 'postgres'
password = pw
host = 'localhost'
port = 5432
database_name = 'bike_shop'
engine = create_engine(f'{protocol}://{username}:{password}@{host}:{port}/{database_name}')
   
connection = engine.connect()

# %%
customers = pd.read_sql('select * from customers', connection)

# %%
customers.head()
# Out:
#    CustomerKey Prefix  FirstName LastName  BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG   4/8/1966             M      M
# 1        11001    MR.     EUGENE    HUANG  5/14/1965             S      M
# 2        11002    MR.      RUBEN   TORRES  8/12/1965             M      M
# 3        11003    MS.    CHRISTY      ZHU  2/15/1968             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON   8/8/1968             S      F
#
#                      EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com     $90,000               2      Bachelors
# 1    eugene10@adventure-works.com     $60,000               3      Bachelors
# 2     ruben35@adventure-works.com     $60,000               3      Bachelors
# 3   christy12@adventure-works.com     $70,000               0      Bachelors
# 4  elizabeth5@adventure-works.com     $80,000               5      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y
# 3  Professional         N
# 4  Professional         Y

# %%
products = pd.read_sql('select * from products', connection)

# %%
products.head()
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 1         215                     31    HL-U509  Sport-100 Helmet, Black
# 2         218                     23  SO-B909-M   Mountain Bike Socks, M
# 3         219                     23  SO-B909-L   Mountain Bike Socks, L
# 4         220                     31  HL-U509-B   Sport-100 Helmet, Blue
#
#              ModelName                                 ProductDescription  \
# 0            Sport-100  Universal fit, well-vented, lightweight , snap...
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4            Sport-100  Universal fit, well-vented, lightweight , snap...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# 0          Red           0            0      13.0863       34.9900
# 1        Black           0            0      12.0278       33.6442
# 2        White           M            U       3.3963        9.5000
# 3        White           L            U       3.3963        9.5000
# 4         Blue           0            0      12.0278       33.6442

# %%
sales_2015 = pd.read_sql('select * from Sales_2015', connection)

# %%
sales_2015
# Out:
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2015   9/21/2001     SO45080         332        14657
# 1       1/1/2015   12/5/2001     SO45079         312        29255
# 2       1/1/2015  10/29/2001     SO45082         350        11455
# 3       1/1/2015  11/16/2001     SO45081         338        26782
# 4       1/2/2015  12/15/2001     SO45083         312        14947
# ...          ...         ...         ...         ...          ...
# 2625  12/31/2015  11/29/2002     SO48728         354        13111
# 2626  12/31/2015  11/14/2002     SO48729         324        26563
# 2627  12/31/2015   12/2/2002     SO48724         340        20722
# 2628  12/31/2015   10/9/2002     SO48723         369        14944
# 2629  12/31/2015  11/22/2002     SO48726         383        24915
#
#       TerritoryKey  OrderLineItem  OrderQuantity
# 0                1              1              1
# 1                4              1              1
# 2                9              1              1
# 3                6              1              1
# 4               10              1              1
# ...            ...            ...            ...
# 2625             9              1              1
# 2626             9              1              1
# 2627             8              1              1
# 2628             7              1              1
# 2629             9              1              1
#
# [2630 rows x 8 columns]

# %%
sales_2016 = pd.read_sql('select * from Sales_2016', connection)

# %%
sales_2016
# Out:
#         OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0        1/1/2016  10/17/2002     SO48797         385        14335
# 1        1/1/2016   9/30/2002     SO48802         383        24923
# 2        1/1/2016  11/29/2002     SO48801         326        15493
# 3        1/1/2016  11/16/2002     SO48799         352        26708
# 4        1/1/2016  12/16/2002     SO48798         369        23332
# ...           ...         ...         ...         ...          ...
# 23930  12/31/2016  12/11/2003     SO61111         591        17841
# 23931  12/31/2016  10/15/2003     SO61147         464        12146
# 23932  12/31/2016   11/4/2003     SO61147         528        12146
# 23933  12/31/2016   11/9/2003     SO61147         215        12146
# 23934  12/31/2016  11/16/2003     SO61147         537        12146
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              1              1
# 1                 9              1              1
# 2                 1              1              1
# 3                 4              1              1
# 4                 9              1              1
# ...             ...            ...            ...
# 23930            10              1              1
# 23931             4              4              2
# 23932             4              1              2
# 23933             4              3              1
# 23934             4              2              1
#
# [23935 rows x 8 columns]

# %%
sales_2017 = pd.read_sql('select * from Sales_2017', connection)

# %%
sales_2017
# Out:
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2017  12/13/2003     SO61285         529        23791
# 1       1/1/2017   9/24/2003     SO61285         214        23791
# 2       1/1/2017    9/4/2003     SO61285         540        23791
# 3       1/1/2017   9/28/2003     SO61301         529        16747
# 4       1/1/2017  10/21/2003     SO61301         377        16747
# ...          ...         ...         ...         ...          ...
# 29476  6/30/2017   3/22/2004     SO74143         477        28517
# 29477  6/30/2017   3/15/2004     SO74143         479        28517
# 29478  6/30/2017    4/8/2004     SO74143         606        28517
# 29479  6/30/2017   5/15/2004     SO74124         480        21676
# 29480  6/30/2017    5/4/2004     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              2              2
# 1                 1              3              1
# 2                 1              1              1
# 3                 1              2              2
# 4                 1              1              1
# ...             ...            ...            ...
# 29476            10              3              2
# 29477            10              2              1
# 29478            10              1              1
# 29479             7              2              2
# 29480             7              1              2
#
# [29481 rows x 8 columns]

# %%
product_cat = pd.read_sql('select * from p_categories', connection)

# %%
product_cat
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
product_subcat = pd.read_sql('select * from p_subcategories', connection)

# %%
product_subcat
# Out:
#     ProductSubcategoryKey    SubcategoryName  ProductCategoryKey
# 0                       1     Mountain Bikes                   1
# 1                       2         Road Bikes                   1
# 2                       3      Touring Bikes                   1
# 3                       4         Handlebars                   2
# 4                       5    Bottom Brackets                   2
# 5                       6             Brakes                   2
# 6                       7             Chains                   2
# 7                       8          Cranksets                   2
# 8                       9        Derailleurs                   2
# 9                      10              Forks                   2
# 10                     11           Headsets                   2
# 11                     12    Mountain Frames                   2
# 12                     13             Pedals                   2
# 13                     14        Road Frames                   2
# 14                     15            Saddles                   2
# 15                     16     Touring Frames                   2
# 16                     17             Wheels                   2
# 17                     18         Bib-Shorts                   3
# 18                     19               Caps                   3
# 19                     20             Gloves                   3
# 20                     21            Jerseys                   3
# 21                     22             Shorts                   3
# 22                     23              Socks                   3
# 23                     24             Tights                   3
# 24                     25              Vests                   3
# 25                     26         Bike Racks                   4
# 26                     27        Bike Stands                   4
# 27                     28  Bottles and Cages                   4
# 28                     29           Cleaners                   4
# 29                     30            Fenders                   4
# 30                     31            Helmets                   4
# 31                     32    Hydration Packs                   4
# 32                     33             Lights                   4
# 33                     34              Locks                   4
# 34                     35           Panniers                   4
# 35                     36              Pumps                   4
# 36                     37    Tires and Tubes                   4

# %%
territories = pd.read_sql('select * from territories', connection)

# %%
territories
# Out:
#    SalesTerritoryKey          Region         Country      Continent
# 0                  1       Northwest   United States  North America
# 1                  2       Northeast   United States  North America
# 2                  3         Central   United States  North America
# 3                  4       Southwest   United States  North America
# 4                  5       Southeast   United States  North America
# 5                  6          Canada          Canada  North America
# 6                  7          France          France         Europe
# 7                  8         Germany         Germany         Europe
# 8                  9       Australia       Australia        Pacific
# 9                 10  United Kingdom  United Kingdom         Europe

# %%
returns = pd.read_sql('select * from returns', connection)

# %%
returns
# Out:
#      ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0     1/18/2015             9         312               1
# 1     1/18/2015            10         310               1
# 2     1/21/2015             8         346               1
# 3     1/22/2015             4         311               1
# 4      2/2/2015             6         312               1
# ...         ...           ...         ...             ...
# 1804  6/30/2017             6         491               1
# 1805  6/30/2017             8         477               1
# 1806  6/30/2017             9         477               1
# 1807  6/30/2017            10         223               1
# 1808  6/30/2017            10         477               1
#
# [1809 rows x 4 columns]

# %%
calendar = pd.read_sql('select * from calendar', connection)

# %%
calendar
# Out:
#           Date
# 0     1/1/2015
# 1     1/2/2015
# 2     1/3/2015
# 3     1/4/2015
# 4     1/5/2015
# ..         ...
# 907  6/26/2017
# 908  6/27/2017
# 909  6/28/2017
# 910  6/29/2017
# 911  6/30/2017
#
# [912 rows x 1 columns]

# %%
sales = [sales_2015, sales_2016, sales_2017]

# %%
all_sales = pd.concat(sales)

# %%
all_sales
# Out:
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2015   9/21/2001     SO45080         332        14657
# 1       1/1/2015   12/5/2001     SO45079         312        29255
# 2       1/1/2015  10/29/2001     SO45082         350        11455
# 3       1/1/2015  11/16/2001     SO45081         338        26782
# 4       1/2/2015  12/15/2001     SO45083         312        14947
# ...          ...         ...         ...         ...          ...
# 29476  6/30/2017   3/22/2004     SO74143         477        28517
# 29477  6/30/2017   3/15/2004     SO74143         479        28517
# 29478  6/30/2017    4/8/2004     SO74143         606        28517
# 29479  6/30/2017   5/15/2004     SO74124         480        21676
# 29480  6/30/2017    5/4/2004     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              1              1
# 1                 4              1              1
# 2                 9              1              1
# 3                 6              1              1
# 4                10              1              1
# ...             ...            ...            ...
# 29476            10              3              2
# 29477            10              2              1
# 29478            10              1              1
# 29479             7              2              2
# 29480             7              1              2
#
# [56046 rows x 8 columns]

# %%
all_sales.rename(columns={'TerritoryKey': 'SalesTerritoryKey'},inplace=True)

# %%
all_sales
# Out:
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2015   9/21/2001     SO45080         332        14657
# 1       1/1/2015   12/5/2001     SO45079         312        29255
# 2       1/1/2015  10/29/2001     SO45082         350        11455
# 3       1/1/2015  11/16/2001     SO45081         338        26782
# 4       1/2/2015  12/15/2001     SO45083         312        14947
# ...          ...         ...         ...         ...          ...
# 29476  6/30/2017   3/22/2004     SO74143         477        28517
# 29477  6/30/2017   3/15/2004     SO74143         479        28517
# 29478  6/30/2017    4/8/2004     SO74143         606        28517
# 29479  6/30/2017   5/15/2004     SO74124         480        21676
# 29480  6/30/2017    5/4/2004     SO74124         538        21676
#
#        SalesTerritoryKey  OrderLineItem  OrderQuantity
# 0                      1              1              1
# 1                      4              1              1
# 2                      9              1              1
# 3                      6              1              1
# 4                     10              1              1
# ...                  ...            ...            ...
# 29476                 10              3              2
# 29477                 10              2              1
# 29478                 10              1              1
# 29479                  7              2              2
# 29480                  7              1              2
#
# [56046 rows x 8 columns]

# %%
all_sales_reset = all_sales.reset_index(drop=True)

# %%
just_sales = all_sales_reset['ProductKey'].value_counts()

# %%
counts = just_sales
plt.bar(counts.index.values,counts.values)
plt.xlabel("Product")
plt.xticks(rotation=90)
plt.ylabel("Sales qty")
plt.show()

# %%
all_sales_reset
# Out:
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2015   9/21/2001     SO45080         332        14657
# 1       1/1/2015   12/5/2001     SO45079         312        29255
# 2       1/1/2015  10/29/2001     SO45082         350        11455
# 3       1/1/2015  11/16/2001     SO45081         338        26782
# 4       1/2/2015  12/15/2001     SO45083         312        14947
# ...          ...         ...         ...         ...          ...
# 56041  6/30/2017   3/22/2004     SO74143         477        28517
# 56042  6/30/2017   3/15/2004     SO74143         479        28517
# 56043  6/30/2017    4/8/2004     SO74143         606        28517
# 56044  6/30/2017   5/15/2004     SO74124         480        21676
# 56045  6/30/2017    5/4/2004     SO74124         538        21676
#
#        SalesTerritoryKey  OrderLineItem  OrderQuantity
# 0                      1              1              1
# 1                      4              1              1
# 2                      9              1              1
# 3                      6              1              1
# 4                     10              1              1
# ...                  ...            ...            ...
# 56041                 10              3              2
# 56042                 10              2              1
# 56043                 10              1              1
# 56044                  7              2              2
# 56045                  7              1              2
#
# [56046 rows x 8 columns]

# %%
territory_sales = pd.merge(territories,all_sales_reset, how="right",on='SalesTerritoryKey')

# %%
territory_sales
# Out:
#        SalesTerritoryKey          Region         Country      Continent  \
# 0                      1       Northwest   United States  North America
# 1                      4       Southwest   United States  North America
# 2                      9       Australia       Australia        Pacific
# 3                      6          Canada          Canada  North America
# 4                     10  United Kingdom  United Kingdom         Europe
# ...                  ...             ...             ...            ...
# 56041                 10  United Kingdom  United Kingdom         Europe
# 56042                 10  United Kingdom  United Kingdom         Europe
# 56043                 10  United Kingdom  United Kingdom         Europe
# 56044                  7          France          France         Europe
# 56045                  7          France          France         Europe
#
#        OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0       1/1/2015   9/21/2001     SO45080         332        14657
# 1       1/1/2015   12/5/2001     SO45079         312        29255
# 2       1/1/2015  10/29/2001     SO45082         350        11455
# 3       1/1/2015  11/16/2001     SO45081         338        26782
# 4       1/2/2015  12/15/2001     SO45083         312        14947
# ...          ...         ...         ...         ...          ...
# 56041  6/30/2017   3/22/2004     SO74143         477        28517
# 56042  6/30/2017   3/15/2004     SO74143         479        28517
# 56043  6/30/2017    4/8/2004     SO74143         606        28517
# 56044  6/30/2017   5/15/2004     SO74124         480        21676
# 56045  6/30/2017    5/4/2004     SO74124         538        21676
#
#        OrderLineItem  OrderQuantity
# 0                  1              1
# 1                  1              1
# 2                  1              1
# 3                  1              1
# 4                  1              1
# ...              ...            ...
# 56041              3              2
# 56042              2              1
# 56043              1              1
# 56044              2              2
# 56045              1              2
#
# [56046 rows x 11 columns]

# %%
product_sales = pd.merge(products,territory_sales, how="right",on='ProductKey')

# %%
product_sales
# Out:
#        ProductKey  ProductSubcategoryKey  ProductSKU             ProductName  \
# 0             332                      2  BK-R50B-58      Road-650 Black, 58
# 1             312                      2  BK-R93R-48        Road-150 Red, 48
# 2             350                      1  BK-M82B-44  Mountain-100 Black, 44
# 3             338                      2  BK-R50B-44      Road-650 Black, 44
# 4             312                      2  BK-R93R-48        Road-150 Red, 48
# ...           ...                    ...         ...                     ...
# 56041         477                     28     WB-H098   Water Bottle - 30 oz.
# 56042         479                     28     BC-R205        Road Bottle Cage
# 56043         606                      2  BK-R19B-52      Road-750 Black, 52
# 56044         480                     37     PK-7098     Patch Kit/8 Patches
# 56045         538                     37     TI-R092            LL Road Tire
#
#               ModelName                                 ProductDescription  \
# 0              Road-650  Value-priced bike with many features of our to...
# 1              Road-150  This bike is ridden by race winners. Developed...
# 2          Mountain-100  Top-of-the-line competition mountain bike. Per...
# 3              Road-650  Value-priced bike with many features of our to...
# 4              Road-150  This bike is ridden by race winners. Developed...
# ...                 ...                                                ...
# 56041      Water Bottle   AWC logo water bottle - holds 30 oz; leak-proof.
# 56042  Road Bottle Cage  Aluminum cage is lighter than our mountain ver...
# 56043          Road-750  Entry level adult bike; offers a comfortable r...
# 56044         Patch kit  Includes 8 different size patches, glue and sa...
# 56045      LL Road Tire  Same great treads as more expensive tire with ...
#
#       ProductColor ProductSize ProductStyle  ProductCost  ...  \
# 0            Black          58            U     413.1463  ...
# 1              Red          48            U    2171.2942  ...
# 2            Black          44            U    1898.0944  ...
# 3            Black          44            U     413.1463  ...
# 4              Red          48            U    2171.2942  ...
# ...            ...         ...          ...          ...  ...
# 56041         None           0            0       1.8663  ...
# 56042         None           0            0       3.3623  ...
# 56043        Black          52            U     343.6496  ...
# 56044         None           0            0       0.8565  ...
# 56045         None           0            0       8.0373  ...
#
#        SalesTerritoryKey          Region         Country      Continent  \
# 0                      1       Northwest   United States  North America
# 1                      4       Southwest   United States  North America
# 2                      9       Australia       Australia        Pacific
# 3                      6          Canada          Canada  North America
# 4                     10  United Kingdom  United Kingdom         Europe
# ...                  ...             ...             ...            ...
# 56041                 10  United Kingdom  United Kingdom         Europe
# 56042                 10  United Kingdom  United Kingdom         Europe
# 56043                 10  United Kingdom  United Kingdom         Europe
# 56044                  7          France          France         Europe
# 56045                  7          France          France         Europe
#
#        OrderDate   StockDate OrderNumber CustomerKey  OrderLineItem  \
# 0       1/1/2015   9/21/2001     SO45080       14657              1
# 1       1/1/2015   12/5/2001     SO45079       29255              1
# 2       1/1/2015  10/29/2001     SO45082       11455              1
# 3       1/1/2015  11/16/2001     SO45081       26782              1
# 4       1/2/2015  12/15/2001     SO45083       14947              1
# ...          ...         ...         ...         ...            ...
# 56041  6/30/2017   3/22/2004     SO74143       28517              3
# 56042  6/30/2017   3/15/2004     SO74143       28517              2
# 56043  6/30/2017    4/8/2004     SO74143       28517              1
# 56044  6/30/2017   5/15/2004     SO74124       21676              2
# 56045  6/30/2017    5/4/2004     SO74124       21676              1
#
#        OrderQuantity
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 56041              2
# 56042              1
# 56043              1
# 56044              2
# 56045              2
#
# [56046 rows x 21 columns]

# %%
customer_sales = pd.merge(customers,product_sales, how="right",on='CustomerKey')

# %%
customer_sales
# Out:
#        CustomerKey Prefix  FirstName    LastName   BirthDate MaritalStatus  \
# 0            14657    MR.       JOHN      THOMAS  11/11/1958             M
# 1            29255    MR.       KYLE  WASHINGTON   4/11/1955             S
# 2            11455    MR.       ROSS        SANZ   4/21/1974             M
# 3            26782    MR.       SETH       LEWIS   9/25/1980             S
# 4            14947    MR.  ALEJANDRO        CHEN   1/11/1965             S
# ...            ...    ...        ...         ...         ...           ...
# 56041        28517    MR.       TROY    GONZALEZ   7/26/1969             S
# 56042        28517    MR.       TROY    GONZALEZ   7/26/1969             S
# 56043        28517    MR.       TROY    GONZALEZ   7/26/1969             S
# 56044        21676    MS.    VALERIE         GUO    7/8/1971             S
# 56045        21676    MS.    VALERIE         GUO    7/8/1971             S
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  ...  \
# 0          M      john48@adventure-works.com     $80,000               1  ...
# 1          M       kyle8@adventure-works.com     $80,000               3  ...
# 2          M      ross38@adventure-works.com    $100,000               0  ...
# 3          M      seth20@adventure-works.com     $30,000               0  ...
# 4          M  alejandro4@adventure-works.com     $20,000               2  ...
# ...      ...                             ...          ...            ...  ...
# 56041      M      troy20@adventure-works.com     $20,000               0  ...
# 56042      M      troy20@adventure-works.com     $20,000               0  ...
# 56043      M      troy20@adventure-works.com     $20,000               0  ...
# 56044      F   valerie19@adventure-works.com     $20,000               0  ...
# 56045      F   valerie19@adventure-works.com     $20,000               0  ...
#
#       ProductPrice SalesTerritoryKey          Region         Country  \
# 0         699.0982                 1       Northwest   United States
# 1        3578.2700                 4       Southwest   United States
# 2        3374.9900                 9       Australia       Australia
# 3         699.0982                 6          Canada          Canada
# 4        3578.2700                10  United Kingdom  United Kingdom
# ...            ...               ...             ...             ...
# 56041       4.9900                10  United Kingdom  United Kingdom
# 56042       8.9900                10  United Kingdom  United Kingdom
# 56043     539.9900                10  United Kingdom  United Kingdom
# 56044       2.2900                 7          France          France
# 56045      21.4900                 7          France          France
#
#            Continent  OrderDate   StockDate OrderNumber OrderLineItem  \
# 0      North America   1/1/2015   9/21/2001     SO45080             1
# 1      North America   1/1/2015   12/5/2001     SO45079             1
# 2            Pacific   1/1/2015  10/29/2001     SO45082             1
# 3      North America   1/1/2015  11/16/2001     SO45081             1
# 4             Europe   1/2/2015  12/15/2001     SO45083             1
# ...              ...        ...         ...         ...           ...
# 56041         Europe  6/30/2017   3/22/2004     SO74143             3
# 56042         Europe  6/30/2017   3/15/2004     SO74143             2
# 56043         Europe  6/30/2017    4/8/2004     SO74143             1
# 56044         Europe  6/30/2017   5/15/2004     SO74124             2
# 56045         Europe  6/30/2017    5/4/2004     SO74124             1
#
#       OrderQuantity
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 56041             2
# 56042             1
# 56043             1
# 56044             2
# 56045             2
#
# [56046 rows x 33 columns]

# %%
categories = pd.merge(product_subcat,product_cat, how="right",on='ProductCategoryKey')

# %%
categories
# Out:
#     ProductSubcategoryKey    SubcategoryName  ProductCategoryKey CategoryName
# 0                       1     Mountain Bikes                   1        Bikes
# 1                       2         Road Bikes                   1        Bikes
# 2                       3      Touring Bikes                   1        Bikes
# 3                       4         Handlebars                   2   Components
# 4                       5    Bottom Brackets                   2   Components
# 5                       6             Brakes                   2   Components
# 6                       7             Chains                   2   Components
# 7                       8          Cranksets                   2   Components
# 8                       9        Derailleurs                   2   Components
# 9                      10              Forks                   2   Components
# 10                     11           Headsets                   2   Components
# 11                     12    Mountain Frames                   2   Components
# 12                     13             Pedals                   2   Components
# 13                     14        Road Frames                   2   Components
# 14                     15            Saddles                   2   Components
# 15                     16     Touring Frames                   2   Components
# 16                     17             Wheels                   2   Components
# 17                     18         Bib-Shorts                   3     Clothing
# 18                     19               Caps                   3     Clothing
# 19                     20             Gloves                   3     Clothing
# 20                     21            Jerseys                   3     Clothing
# 21                     22             Shorts                   3     Clothing
# 22                     23              Socks                   3     Clothing
# 23                     24             Tights                   3     Clothing
# 24                     25              Vests                   3     Clothing
# 25                     26         Bike Racks                   4  Accessories
# 26                     27        Bike Stands                   4  Accessories
# 27                     28  Bottles and Cages                   4  Accessories
# 28                     29           Cleaners                   4  Accessories
# 29                     30            Fenders                   4  Accessories
# 30                     31            Helmets                   4  Accessories
# 31                     32    Hydration Packs                   4  Accessories
# 32                     33             Lights                   4  Accessories
# 33                     34              Locks                   4  Accessories
# 34                     35           Panniers                   4  Accessories
# 35                     36              Pumps                   4  Accessories
# 36                     37    Tires and Tubes                   4  Accessories

# %%
all_data = pd.merge(categories,customer_sales, how="right",on='ProductSubcategoryKey')

# %%
all_data
# Out:
#        ProductSubcategoryKey    SubcategoryName  ProductCategoryKey  \
# 0                          2         Road Bikes                   1
# 1                          2         Road Bikes                   1
# 2                          1     Mountain Bikes                   1
# 3                          2         Road Bikes                   1
# 4                          2         Road Bikes                   1
# ...                      ...                ...                 ...
# 56041                     28  Bottles and Cages                   4
# 56042                     28  Bottles and Cages                   4
# 56043                      2         Road Bikes                   1
# 56044                     37    Tires and Tubes                   4
# 56045                     37    Tires and Tubes                   4
#
#       CategoryName  CustomerKey Prefix  FirstName    LastName   BirthDate  \
# 0            Bikes        14657    MR.       JOHN      THOMAS  11/11/1958
# 1            Bikes        29255    MR.       KYLE  WASHINGTON   4/11/1955
# 2            Bikes        11455    MR.       ROSS        SANZ   4/21/1974
# 3            Bikes        26782    MR.       SETH       LEWIS   9/25/1980
# 4            Bikes        14947    MR.  ALEJANDRO        CHEN   1/11/1965
# ...            ...          ...    ...        ...         ...         ...
# 56041  Accessories        28517    MR.       TROY    GONZALEZ   7/26/1969
# 56042  Accessories        28517    MR.       TROY    GONZALEZ   7/26/1969
# 56043        Bikes        28517    MR.       TROY    GONZALEZ   7/26/1969
# 56044  Accessories        21676    MS.    VALERIE         GUO    7/8/1971
# 56045  Accessories        21676    MS.    VALERIE         GUO    7/8/1971
#
#       MaritalStatus  ... ProductPrice SalesTerritoryKey          Region  \
# 0                 M  ...     699.0982                 1       Northwest
# 1                 S  ...    3578.2700                 4       Southwest
# 2                 M  ...    3374.9900                 9       Australia
# 3                 S  ...     699.0982                 6          Canada
# 4                 S  ...    3578.2700                10  United Kingdom
# ...             ...  ...          ...               ...             ...
# 56041             S  ...       4.9900                10  United Kingdom
# 56042             S  ...       8.9900                10  United Kingdom
# 56043             S  ...     539.9900                10  United Kingdom
# 56044             S  ...       2.2900                 7          France
# 56045             S  ...      21.4900                 7          France
#
#               Country      Continent  OrderDate   StockDate  OrderNumber  \
# 0       United States  North America   1/1/2015   9/21/2001      SO45080
# 1       United States  North America   1/1/2015   12/5/2001      SO45079
# 2           Australia        Pacific   1/1/2015  10/29/2001      SO45082
# 3              Canada  North America   1/1/2015  11/16/2001      SO45081
# 4      United Kingdom         Europe   1/2/2015  12/15/2001      SO45083
# ...               ...            ...        ...         ...          ...
# 56041  United Kingdom         Europe  6/30/2017   3/22/2004      SO74143
# 56042  United Kingdom         Europe  6/30/2017   3/15/2004      SO74143
# 56043  United Kingdom         Europe  6/30/2017    4/8/2004      SO74143
# 56044          France         Europe  6/30/2017   5/15/2004      SO74124
# 56045          France         Europe  6/30/2017    5/4/2004      SO74124
#
#       OrderLineItem OrderQuantity
# 0                 1             1
# 1                 1             1
# 2                 1             1
# 3                 1             1
# 4                 1             1
# ...             ...           ...
# 56041             3             2
# 56042             2             1
# 56043             1             1
# 56044             2             2
# 56045             1             2
#
# [56046 rows x 36 columns]
