# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Customers Data

# %%
csv_file0 = "Data/customers.csv"
Customers_df = pd.read_csv(csv_file0, encoding="ISO-8859_1")

# %%
# Customers_df.describe

# %%
Customers_df.head()
# Out:
#    CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG  1966-04-08             M      M
# 1        11001    MR.     EUGENE    HUANG  1965-05-14             S      M
# 2        11002    MR.      RUBEN   TORRES  1965-08-12             M      M
# 3        11003    MS.    CHRISTY      ZHU  1968-02-15             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON  1968-08-08             S      F
#
#                      EmailAddress  AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com         90000              2      Bachelors
# 1    eugene10@adventure-works.com         60000              3      Bachelors
# 2     ruben35@adventure-works.com         60000              3      Bachelors
# 3   christy12@adventure-works.com         70000              0      Bachelors
# 4  elizabeth5@adventure-works.com         80000              5      Bachelors
#
#      Occupation HomeOwner
# ...

# %%
# Create salary lists

Customer_Salary_counts = [Customers_df['AnnualIncome'].value_counts(dropna=False)]

Customer_Salary_counts
# Out:
# [60000     3072
#  40000     2688
#  70000     2313
#  30000     2236
#  20000     1745
#  80000     1325
#  10000     1135
#  90000      830
#  50000      661
#  100000     559
#  130000     501
#  110000     459
#  120000     324
#  170000     109
#  150000     100
#  160000      91
#  Name: AnnualIncome, dtype: int64]

# %%
Customer_Salary_counts_df = pd.DataFrame(Customer_counts)
Customer_Salary_counts_df
# Out:
#               60000   40000   70000   30000   20000   80000   10000   90000   \
# AnnualIncome    3072    2688    2313    2236    1745    1325    1135     830
#
#               50000   100000  130000  110000  120000  170000  150000  160000
# AnnualIncome     661     559     501     459     324     109     100      91

# %%
# Trnaspose DF 
Customer_Salary_counts_df_transposed = Customer_Salary_counts_df.transpose()
Customer_Salary_counts_df_transposed
# Out:
#         AnnualIncome
# 60000           3072
# 40000           2688
# 70000           2313
# 30000           2236
# 20000           1745
# 80000           1325
# 10000           1135
# 90000            830
# 50000            661
# 100000           559
# 130000           501
# 110000           459
# 120000           324
# 170000           109
# 150000           100
# 160000            91

# %%
# Reset the index name to Sariaries
# Customer_Salary_counts_df_transposed.reset_index()
# Out:
#      index  AnnualIncome
# 0    60000          3072
# 1    40000          2688
# 2    70000          2313
# 3    30000          2236
# 4    20000          1745
# 5    80000          1325
# 6    10000          1135
# 7    90000           830
# 8    50000           661
# 9   100000           559
# 10  130000           501
# 11  110000           459
# 12  120000           324
# 13  170000           109
# 14  150000           100
# 15  160000            91

# %%
# rename index as 'salary'   ####does not work  #######
Customer_Salary_counts_df_transposed2  = t.rename(columns={' ': 'Salaries'}, inplace=True)
Customer_Salary_counts_df_transposed2

# %%
#matplotlib.pyplot.bar()
#bar(x, height, color=None)

#c = ['red', 'yellow', 'black', 'blue', 'orange','green', 'pink','c', 'orange', 'red', 'yellow', 
#                   'blue', 'orange','green', 'pink','c']

t.plot(kind='bar', color = 'm')
plt.grid()
#plt.fig(figsize=(6,10))

plt.xlabel("Salary")
plt.ylabel("Customer Count")
plt.title("Customer Count of Salaries")
plt.show()

# %% [markdown]
# ## Categories Data

# %%
csv_file0 = "Data/categories.csv"
Categories_df = pd.read_csv(csv_file0, encoding="ISO-8859_1")

# %%
#Categories_df.describe

# %%
Categories_df.head()
# Out:
#    ProductSubcategoryKey  SubcategoryName  ProductCategoryKey CategoryName
# 0                      1   Mountain Bikes                   1        Bikes
# 1                      2       Road Bikes                   1        Bikes
# 2                      3    Touring Bikes                   1        Bikes
# 3                      4       Handlebars                   2   Components
# 4                      5  Bottom Brackets                   2   Components

# %%
#Categories_df.CategoryName

# %%
SubcategoryName = (Categories_df.SubcategoryName)
print(len(SubcategoryName))
# Out:
# 37

# %%
ProductCategoryKey = (Categories_df.ProductCategoryKey)
print(len(ProductCategoryKey))
# Out:
# 37

# %%
fig = plt.figure(1, figsize=(10,15))

plt.pie(ProductCategoryKey, explode=explode, labels= SubcategoryName, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=190)

colors = 'b','g','r','c','m','yellow','k','b','c',"tab:blue", "tab:orange", "tab:green", "red", "blueviolet", "yellow", "tab:pink", "tab:gray", "tab:olive", "tab:cyan",'b','g','r','c','m','yellow','k','b','lime',"tab:blue", "tab:orange", "tab:green", "red", "tab:purple", "yellow", "tab:pink", "mediumblue", "tab:olive"
explode = (0,0,0.25,0,0,0.1,0,0,0.4,0,0,0.25,0,0,0.5,0,0,0.25,0,0,0,0.3,0,0,00.5,0,0,0.25,0,0.5,0,0.25,0,0,0.25,0,0)
plt.title("Sample Pie plot")
#plt.axis("equal")
plt.show()

# %%
ProductCategoryKey
# 37 in total 
# three 1's
# fourteen 2's
# eight 3's
# twelve 4's

# %% [markdown]
# ## Products

# %%
csv_file0 = "Data/products.csv"
Products_df = pd.read_csv(csv_file0, encoding="ISO-8859_1")

# %%
# Products_df.describe

# %%
Products_df.head()
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 1         215                     31    HL-U509  Sport-100 Helmet, Black
# 2         218                     23  SO-B909-M   Mountain Bike Socks, M
# 3         219                     23  SO-B909-L   Mountain Bike Socks, L
# 4         220                     31  HL-U509-B   Sport-100 Helmet, Blue
#
#              ModelName                                 ProductDescription  \
# 0            Sport-100  Universal fit, well-vented, lightweight , snap...
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4            Sport-100  Universal fit, well-vented, lightweight , snap...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# ...

# %% [markdown]
# ## Returns Data

# %%
csv_file0 = "Data/returns.csv"
Returns_df = pd.read_csv(csv_file0, encoding="ISO-8859_1")

# %%
# Returns_df.describe

# %%
Returns_df.head()
# Out:
#    ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0  2015-01-18             9         312               1
# 1  2015-01-18            10         310               1
# 2  2015-01-21             8         346               1
# 3  2015-01-22             4         311               1
# 4  2015-02-02             6         312               1

# %%
# Retruns_data = Returns_df.ReturnDate

# %%
# returns_data

# %%
# remove the hyphen in the Returns DF
Returns_df['ReturnDate'] = Returns_df['ReturnDate'].str.replace('-', '')

# %%
# Removed the hyphens in ReturnsDate column 
Returns_df
# Out:
#      ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0      20150118             9         312               1
# 1      20150118            10         310               1
# 2      20150121             8         346               1
# 3      20150122             4         311               1
# 4      20150202             6         312               1
# ...         ...           ...         ...             ...
# 1804   20170630             6         491               1
# 1805   20170630             8         477               1
# 1806   20170630             9         477               1
# 1807   20170630            10         223               1
# 1808   20170630            10         477               1
#
# [1809 rows x 4 columns]

# %%
# Convert 'ReturnDate' column to datetime format
Returns_df['ReturnDate'] = pd.to_datetime(Returns_df['ReturnDate'], format = '%Y%m%d')

# %%
# Returns_df.loc[:,"ReturnDate"]
Returns_df
# Out:
#      ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0    2015-01-18             9         312               1
# 1    2015-01-18            10         310               1
# 2    2015-01-21             8         346               1
# 3    2015-01-22             4         311               1
# 4    2015-02-02             6         312               1
# ...         ...           ...         ...             ...
# 1804 2017-06-30             6         491               1
# 1805 2017-06-30             8         477               1
# 1806 2017-06-30             9         477               1
# 1807 2017-06-30            10         223               1
# 1808 2017-06-30            10         477               1
#
# [1809 rows x 4 columns]

# %%
Returns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1809 entries, 0 to 1808
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ReturnDate      1809 non-null   datetime64[ns]
#  1   TerritoryKey    1809 non-null   int64
#  2   ProductKey      1809 non-null   int64
#  3   ReturnQuantity  1809 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 56.7 KB

# %%
# DF with code to sort date required
# *************************TRIED PLOT BUT TOO MUCH DATA MAY NEED TO HAVE SMALLER TIME INTERVALS********************************
Returns_df[(Returns_df["ReturnDate"]> "2017-06-01") & (Returns_df["ReturnDate"] < "2018-01-01")]
# Out:
#      ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 1646 2017-06-02             1         481               1
# 1647 2017-06-02             6         477               1
# 1648 2017-06-03             1         538               1
# 1649 2017-06-03             7         477               1
# 1650 2017-06-03             7         538               1
# ...         ...           ...         ...             ...
# 1804 2017-06-30             6         491               1
# 1805 2017-06-30             8         477               1
# 1806 2017-06-30             9         477               1
# 1807 2017-06-30            10         223               1
# 1808 2017-06-30            10         477               1
#
# [163 rows x 4 columns]

# %%
return_df_2015_jan_july = Returns_df.query("ReturnDate>'2015-01-01' & ReturnDate <'2015-03-01'")

# %%
return_df_2015_jan_july.plot(kind="bar", x="ReturnDate", y="TerritoryKey")

# %%
# now_time = datetime.now()
# now_time

# %% [markdown]
# ## Combined Product Sales

# %%
csv_file0 = "Data/combined_product_sales.csv"
Combined_product_sales_df = pd.read_csv(csv_file0, encoding="ISO-8859_1")

# %%
#Combined_product_sales_df.describe

# %%
Combined_product_sales_df.head()
# Out:
#    ProductSubcategoryKey SubcategoryName  ProductCategoryKey CategoryName  \
# 0                      2      Road Bikes                   1        Bikes
# 1                      2      Road Bikes                   1        Bikes
# 2                      1  Mountain Bikes                   1        Bikes
# 3                      2      Road Bikes                   1        Bikes
# 4                      2      Road Bikes                   1        Bikes
#
#    ProductKey  ProductSKU             ProductName     ModelName  \
# 0         332  BK-R50B-58      Road-650 Black, 58      Road-650
# 1         312  BK-R93R-48        Road-150 Red, 48      Road-150
# 2         350  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3         338  BK-R50B-44      Road-650 Black, 44      Road-650
# 4         312  BK-R93R-48        Road-150 Red, 48      Road-150
#
#                                   ProductDescription ProductColor  ...  \
# ...

# %%
# the unique category names 
Combined_product_sales_df.CategoryName.unique()
# Out:
# array(['Bikes', 'Accessories', 'Clothing'], dtype=object)

# %%
# Scatter plot / Bubble chart ?             ***************https://plotly.com/python/bubble-charts/****************

# %%
import seaborn as sns

# %%
# countries per bike sale
Bikes_sale_df = Combined_product_sales_df[['CategoryName','Country','OrderQuantity']]
Bikes_sale_df = Bikes_sale_df.loc[Bikes_sale_df['CategoryName'] == 'Bikes']
Bikes_sale_df
# Out:
#       CategoryName         Country  OrderQuantity
# 0            Bikes   United States              1
# 1            Bikes   United States              1
# 2            Bikes       Australia              1
# 3            Bikes          Canada              1
# 4            Bikes  United Kingdom              1
# ...            ...             ...            ...
# 56022        Bikes  United Kingdom              1
# 56029        Bikes       Australia              1
# 56031        Bikes   United States              1
# 56034        Bikes          Canada              1
# 56043        Bikes  United Kingdom              1
#
# [13929 rows x 3 columns]

# %%
sns.countplot(data=Bikes_sale_df, x="OrderQuantity",  hue="Country")

# %%
# countries per Accessories sale
Accessories_sale_df = Combined_product_sales_df[['CategoryName','Country','OrderQuantity']]
Accessories_sale_df = Accessories_sale_df.loc[Accessories_sale_df['CategoryName'] == 'Accessories']
Accessories_sale_df
# Out:
#       CategoryName         Country  OrderQuantity
# 4337   Accessories       Australia              1
# 4339   Accessories          France              2
# 4341   Accessories          France              1
# 4342   Accessories          France              1
# 4343   Accessories         Germany              3
# ...            ...             ...            ...
# 56038  Accessories       Australia              1
# 56041  Accessories  United Kingdom              2
# 56042  Accessories  United Kingdom              1
# 56044  Accessories          France              2
# 56045  Accessories          France              2
#
# [33607 rows x 3 columns]

# %%
sns.countplot(data=Accessories_sale_df, x="OrderQuantity",  hue="Country")

# %%
# countries per Components sale
Clothing_sale_df = Combined_product_sales_df[['CategoryName','Country','OrderQuantity']]
Clothing_sale_df = Clothing_sale_df.loc[Clothing_sale_df['CategoryName'] == 'Clothing']
Clothing_sale_df
# Out:
#       CategoryName         Country  OrderQuantity
# 4350      Clothing         Germany              1
# 4360      Clothing          Canada              1
# 4365      Clothing   United States              1
# 4377      Clothing       Australia              1
# 4379      Clothing         Germany              1
# ...            ...             ...            ...
# 56014     Clothing   United States              1
# 56021     Clothing  United Kingdom              2
# 56032     Clothing   United States              1
# 56039     Clothing       Australia              1
# 56040     Clothing  United Kingdom              2
#
# [8510 rows x 3 columns]

# %%
sns.countplot(data = Clothing_sale_df, x="OrderQuantity",  hue="Country")

# %%
# countries per Clothing sale
bike_sale_df = Combined_product_sales_df[['CategoryName','Country','OrderQuantity']]
bike_sale_df = bike_sale_df.loc[bike_sale_df['CategoryName'] == 'Bikes']
bike_sale_df
