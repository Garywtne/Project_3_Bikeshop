# %%
# !pip install chart_studio

# %%
import pandas as pd
import numpy as np
import scipy as sp
import chart_studio.plotly as py

# %%
import plotly.figure_factory as ff

# %%
df = pd.read_csv("Resources/just_bikes.csv")

#table = ff.create_table(df)
#py.iplot(table, filename='jupyter-table1')

# %%
df
# Out:
#        orderquantity          region     modelname categoryname gender  \
# 0                  1       Northwest      Road-650        Bikes      M
# 1                  1       Southwest      Road-150        Bikes      M
# 2                  1       Australia  Mountain-100        Bikes      M
# 3                  1          Canada      Road-650        Bikes      M
# 4                  1  United Kingdom      Road-150        Bikes      M
# ...              ...             ...           ...          ...    ...
# 13924              1  United Kingdom  Mountain-200        Bikes      F
# 13925              1       Australia      Road-250        Bikes      M
# 13926              1       Northwest    Road-550-W        Bikes      F
# 13927              1          Canada  Mountain-200        Bikes      F
# 13928              1  United Kingdom      Road-750        Bikes      M
#
#         educationlevel
# 0      Partial College
# 1      Partial College
# 2          High School
# ...
